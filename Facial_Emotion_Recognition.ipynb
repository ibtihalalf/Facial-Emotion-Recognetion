# %% [markdown]
# 1.import dataset, preprossing and augmentation

# %%
import os
import shutil
import random
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Dataset Splitting 
source_dir = '/Users/ebtehal/Desktop/expressions3'  
base_dir = 'split_dataset'   

# Create base split folders
for split in ['train', 'val', 'test']:
    os.makedirs(os.path.join(base_dir, split), exist_ok=True)

# Split each class folder
for class_name in os.listdir(source_dir):
    class_path = os.path.join(source_dir, class_name)
    if not os.path.isdir(class_path):
        continue
    
    images = os.listdir(class_path)
    random.shuffle(images)

    train_imgs, temp_imgs = train_test_split(images, test_size=0.2, random_state=42)
    val_imgs, test_imgs = train_test_split(temp_imgs, test_size=0.5, random_state=42)

    for split_name, split_imgs in zip(['train', 'val', 'test'], [train_imgs, val_imgs, test_imgs]):
        split_class_dir = os.path.join(base_dir, split_name, class_name)
        os.makedirs(split_class_dir, exist_ok=True)
        for img in split_imgs:
            src = os.path.join(class_path, img)
            dst = os.path.join(split_class_dir, img)
            shutil.copy2(src, dst)

# Images Preprocessing 
img_height, img_width = 64, 64
batch_size = 32

train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')
test_dir = os.path.join(base_dir, 'test')

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)

val_test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir, target_size=(img_height, img_width), batch_size=batch_size, class_mode='categorical')

val_generator = val_test_datagen.flow_from_directory(
    val_dir, target_size=(img_height, img_width), batch_size=batch_size, class_mode='categorical')

test_generator = val_test_datagen.flow_from_directory(
    test_dir, target_size=(img_height, img_width), batch_size=batch_size, class_mode='categorical', shuffle=False)

print("Train samples:", train_generator.samples)
print("Validation samples:", val_generator.samples)
print("Test samples:", test_generator.samples)

class_names = list(train_generator.class_indices.keys())
images, labels = next(train_generator)

plt.figure(figsize=(10, 6))
for i in range(6):
    plt.subplot(2, 3, i+1)
    plt.imshow(images[i])
    class_index = np.argmax(labels[i])
    plt.title(f"Class: {class_names[class_index]}")
    plt.axis('off')

plt.suptitle("Augmented RGB Training Images (64x64)")
plt.tight_layout()
plt.show()
# Out:
# Found 695 images belonging to 7 classes.
# Found 285 images belonging to 7 classes.
# Found 297 images belonging to 7 classes.
# Train samples: 695
# Validation samples: 285
# Test samples: 297

# %% [markdown]
# 2.CNN model with optimal hyperparameters

# %%
import tensorflow as tf
from tensorflow.keras import layers, models 
from tensorflow.keras.optimizers import Adam

input_shape = (64, 64, 3)
num_classes = train_generator.num_classes

model = models.Sequential([
    # Conv Layer 1
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape),
    layers.MaxPooling2D((2, 2)),

    # Conv Layer 2
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),

    # Conv Layer 3
    layers.Conv2D(128, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),

    layers.Flatten(),
    layers.Dense(128, activation='relu'),  # Fully Connected Layer
    layers.Dense(7, activation='softmax')  # Output Layer
])

# Compile
optimizer = Adam(learning_rate=0.0001)
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_23"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_66 (Conv2D)              │ (None, 62, 62, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_66 (MaxPooling2D) │ (None, 31, 31, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_67 (Conv2D)              │ (None, 29, 29, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_67 (MaxPooling2D) │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_68 (Conv2D)              │ (None, 12, 12, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_68 (MaxPooling2D) │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_18 (Flatten)            │ (None, 4608)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_64 (Dense)                │ (None, 128)            │       589,952 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_65 (Dense)                │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 684,103 (2.61 MB)
#  Trainable params: 684,103 (2.61 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# 3.Train the basic CNN model

# %%
epochs = 150

history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=val_generator
)
# Out:
# Epoch 1/150
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.1658 - loss: 1.9420 - val_accuracy: 0.2105 - val_loss: 1.9160
# Epoch 2/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.2135 - loss: 1.9096 - val_accuracy: 0.2386 - val_loss: 1.8956
# Epoch 3/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.2398 - loss: 1.8894 - val_accuracy: 0.2596 - val_loss: 1.8562
# Epoch 4/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.2665 - loss: 1.8600 - val_accuracy: 0.2737 - val_loss: 1.8158
# Epoch 5/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.3000 - loss: 1.8058 - val_accuracy: 0.3333 - val_loss: 1.7513
# Epoch 6/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.3501 - loss: 1.7666 - val_accuracy: 0.3333 - val_loss: 1.6955
# Epoch 7/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.3585 - loss: 1.7104 - val_accuracy: 0.3123 - val_loss: 1.6951
# Epoch 8/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.3530 - loss: 1.6815 - val_accuracy: 0.3368 - val_loss: 1.6453
# Epoch 9/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.3182 - loss: 1.6680 - val_accuracy: 0.3649 - val_loss: 1.6106
# Epoch 10/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.3801 - loss: 1.6143 - val_accuracy: 0.3649 - val_loss: 1.5887
# Epoch 11/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.3720 - loss: 1.5964 - val_accuracy: 0.3193 - val_loss: 1.6294
# Epoch 12/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.3522 - loss: 1.6038 - val_accuracy: 0.3754 - val_loss: 1.5681
# Epoch 13/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.3776 - loss: 1.5706 - val_accuracy: 0.3930 - val_loss: 1.5524
# Epoch 14/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.3773 - loss: 1.5622 - val_accuracy: 0.3614 - val_loss: 1.5475
# Epoch 15/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.3605 - loss: 1.5782 - val_accuracy: 0.3965 - val_loss: 1.5129
# Epoch 16/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.3814 - loss: 1.5932 - val_accuracy: 0.4105 - val_loss: 1.5122
# Epoch 17/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.3840 - loss: 1.5125 - val_accuracy: 0.3404 - val_loss: 1.6122
# Epoch 18/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.3885 - loss: 1.5615 - val_accuracy: 0.3965 - val_loss: 1.5130
# Epoch 19/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.3792 - loss: 1.4974 - val_accuracy: 0.4000 - val_loss: 1.4863
# Epoch 20/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.3690 - loss: 1.5303 - val_accuracy: 0.4211 - val_loss: 1.4814
# Epoch 21/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.3952 - loss: 1.5111 - val_accuracy: 0.4281 - val_loss: 1.4622
# Epoch 22/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.3938 - loss: 1.4954 - val_accuracy: 0.3895 - val_loss: 1.5097
# Epoch 23/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.3931 - loss: 1.4918 - val_accuracy: 0.3930 - val_loss: 1.4989
# Epoch 24/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.4370 - loss: 1.4620 - val_accuracy: 0.4175 - val_loss: 1.4663
# Epoch 25/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.3958 - loss: 1.4888 - val_accuracy: 0.4316 - val_loss: 1.4504
# Epoch 26/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.4111 - loss: 1.4870 - val_accuracy: 0.4386 - val_loss: 1.4267
# Epoch 27/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.3949 - loss: 1.4694 - val_accuracy: 0.4316 - val_loss: 1.4420
# Epoch 28/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.4091 - loss: 1.4787 - val_accuracy: 0.4456 - val_loss: 1.4505
# Epoch 29/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.4155 - loss: 1.4638 - val_accuracy: 0.4281 - val_loss: 1.4181
# Epoch 30/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.3876 - loss: 1.4881 - val_accuracy: 0.4772 - val_loss: 1.3855
# Epoch 31/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.4048 - loss: 1.4460 - val_accuracy: 0.4596 - val_loss: 1.3874
# Epoch 32/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.4064 - loss: 1.4501 - val_accuracy: 0.4702 - val_loss: 1.3942
# Epoch 33/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.4213 - loss: 1.4467 - val_accuracy: 0.4421 - val_loss: 1.4072
# Epoch 34/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.4378 - loss: 1.3816 - val_accuracy: 0.4842 - val_loss: 1.3537
# Epoch 35/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.4143 - loss: 1.3948 - val_accuracy: 0.4596 - val_loss: 1.3515
# Epoch 36/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.4433 - loss: 1.3989 - val_accuracy: 0.4877 - val_loss: 1.3626
# Epoch 37/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.4615 - loss: 1.4132 - val_accuracy: 0.4211 - val_loss: 1.4056
# Epoch 38/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.4243 - loss: 1.4235 - val_accuracy: 0.4632 - val_loss: 1.3469
# Epoch 39/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.4482 - loss: 1.3834 - val_accuracy: 0.4667 - val_loss: 1.3537
# Epoch 40/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.4382 - loss: 1.3554 - val_accuracy: 0.5053 - val_loss: 1.3172
# Epoch 41/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.4704 - loss: 1.3500 - val_accuracy: 0.5053 - val_loss: 1.3470
# Epoch 42/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.4294 - loss: 1.3742 - val_accuracy: 0.5123 - val_loss: 1.3021
# Epoch 43/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.4557 - loss: 1.3429 - val_accuracy: 0.5123 - val_loss: 1.3221
# Epoch 44/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.4285 - loss: 1.4059 - val_accuracy: 0.4912 - val_loss: 1.3023
# Epoch 45/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.4501 - loss: 1.3820 - val_accuracy: 0.4351 - val_loss: 1.3762
# Epoch 46/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.4440 - loss: 1.3859 - val_accuracy: 0.5018 - val_loss: 1.3509
# Epoch 47/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.4609 - loss: 1.3464 - val_accuracy: 0.4632 - val_loss: 1.3457
# Epoch 48/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.4616 - loss: 1.3136 - val_accuracy: 0.5018 - val_loss: 1.3350
# Epoch 49/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.4381 - loss: 1.3651 - val_accuracy: 0.4912 - val_loss: 1.2928
# Epoch 50/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.4881 - loss: 1.2966 - val_accuracy: 0.5544 - val_loss: 1.2592
# Epoch 51/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.4763 - loss: 1.3195 - val_accuracy: 0.5123 - val_loss: 1.2849
# Epoch 52/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.4875 - loss: 1.3291 - val_accuracy: 0.4877 - val_loss: 1.2900
# Epoch 53/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.4892 - loss: 1.2581 - val_accuracy: 0.5158 - val_loss: 1.2787
# Epoch 54/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.4593 - loss: 1.3330 - val_accuracy: 0.4947 - val_loss: 1.3163
# Epoch 55/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.4520 - loss: 1.2627 - val_accuracy: 0.4877 - val_loss: 1.2960
# Epoch 56/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.4456 - loss: 1.3342 - val_accuracy: 0.4947 - val_loss: 1.3022
# Epoch 57/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.4586 - loss: 1.2933 - val_accuracy: 0.5544 - val_loss: 1.2421
# Epoch 58/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.5113 - loss: 1.2454 - val_accuracy: 0.5333 - val_loss: 1.2411
# Epoch 59/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.4856 - loss: 1.2865 - val_accuracy: 0.5263 - val_loss: 1.2567
# Epoch 60/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.4931 - loss: 1.2479 - val_accuracy: 0.5509 - val_loss: 1.2170
# Epoch 61/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.5400 - loss: 1.2552 - val_accuracy: 0.5368 - val_loss: 1.2534
# Epoch 62/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.4779 - loss: 1.2491 - val_accuracy: 0.4737 - val_loss: 1.3450
# Epoch 63/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.4895 - loss: 1.2674 - val_accuracy: 0.5825 - val_loss: 1.2035
# Epoch 64/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.4944 - loss: 1.2603 - val_accuracy: 0.5509 - val_loss: 1.2080
# Epoch 65/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.4631 - loss: 1.3053 - val_accuracy: 0.5193 - val_loss: 1.1991
# Epoch 66/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.5075 - loss: 1.2825 - val_accuracy: 0.5789 - val_loss: 1.2083
# Epoch 67/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.4739 - loss: 1.2593 - val_accuracy: 0.5544 - val_loss: 1.1920
# Epoch 68/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.5147 - loss: 1.2312 - val_accuracy: 0.5930 - val_loss: 1.1670
# Epoch 69/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.4765 - loss: 1.2865 - val_accuracy: 0.4982 - val_loss: 1.2224
# Epoch 70/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.5451 - loss: 1.2194 - val_accuracy: 0.5544 - val_loss: 1.2261
# Epoch 71/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.5178 - loss: 1.1667 - val_accuracy: 0.5298 - val_loss: 1.1900
# Epoch 72/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.5218 - loss: 1.2572 - val_accuracy: 0.5404 - val_loss: 1.2057
# Epoch 73/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.5332 - loss: 1.1992 - val_accuracy: 0.5439 - val_loss: 1.2385
# Epoch 74/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.4898 - loss: 1.2379 - val_accuracy: 0.5965 - val_loss: 1.1082
# Epoch 75/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.5107 - loss: 1.2683 - val_accuracy: 0.5719 - val_loss: 1.1778
# Epoch 76/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.5293 - loss: 1.2107 - val_accuracy: 0.5754 - val_loss: 1.1425
# Epoch 77/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.5353 - loss: 1.1785 - val_accuracy: 0.5649 - val_loss: 1.1326
# Epoch 78/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.5332 - loss: 1.2132 - val_accuracy: 0.5930 - val_loss: 1.1115
# Epoch 79/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.5343 - loss: 1.1643 - val_accuracy: 0.6105 - val_loss: 1.1196
# Epoch 80/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.5512 - loss: 1.2073 - val_accuracy: 0.6105 - val_loss: 1.1244
# Epoch 81/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.5286 - loss: 1.1514 - val_accuracy: 0.6211 - val_loss: 1.1255
# Epoch 82/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5296 - loss: 1.1934 - val_accuracy: 0.6140 - val_loss: 1.0881
# Epoch 83/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.5327 - loss: 1.2169 - val_accuracy: 0.5965 - val_loss: 1.0895
# Epoch 84/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.5242 - loss: 1.1585 - val_accuracy: 0.5965 - val_loss: 1.1026
# Epoch 85/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.5249 - loss: 1.1701 - val_accuracy: 0.5684 - val_loss: 1.1499
# Epoch 86/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.5622 - loss: 1.1400 - val_accuracy: 0.5509 - val_loss: 1.1165
# Epoch 87/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5588 - loss: 1.1264 - val_accuracy: 0.5439 - val_loss: 1.1881
# Epoch 88/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.5403 - loss: 1.1460 - val_accuracy: 0.6351 - val_loss: 1.0583
# Epoch 89/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.5313 - loss: 1.2107 - val_accuracy: 0.5965 - val_loss: 1.1352
# Epoch 90/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.5812 - loss: 1.1390 - val_accuracy: 0.6316 - val_loss: 1.0503
# Epoch 91/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.5862 - loss: 1.1262 - val_accuracy: 0.5930 - val_loss: 1.1243
# Epoch 92/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.5561 - loss: 1.1540 - val_accuracy: 0.5895 - val_loss: 1.1077
# Epoch 93/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.5728 - loss: 1.1184 - val_accuracy: 0.6316 - val_loss: 1.0521
# Epoch 94/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.5661 - loss: 1.1381 - val_accuracy: 0.6281 - val_loss: 1.0762
# Epoch 95/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.5502 - loss: 1.1109 - val_accuracy: 0.5825 - val_loss: 1.0779
# Epoch 96/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.5486 - loss: 1.1211 - val_accuracy: 0.6140 - val_loss: 1.0763
# Epoch 97/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.5774 - loss: 1.0874 - val_accuracy: 0.5860 - val_loss: 1.1880
# Epoch 98/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.5527 - loss: 1.1032 - val_accuracy: 0.6596 - val_loss: 0.9921
# Epoch 99/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.5806 - loss: 1.0985 - val_accuracy: 0.6105 - val_loss: 1.0597
# Epoch 100/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.5340 - loss: 1.1305 - val_accuracy: 0.6456 - val_loss: 1.0591
# Epoch 101/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.5628 - loss: 1.1101 - val_accuracy: 0.6281 - val_loss: 0.9958
# Epoch 102/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.5718 - loss: 1.0791 - val_accuracy: 0.5474 - val_loss: 1.1999
# Epoch 103/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.5860 - loss: 1.0686 - val_accuracy: 0.6351 - val_loss: 1.0238
# Epoch 104/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.5846 - loss: 1.0465 - val_accuracy: 0.6737 - val_loss: 0.9457
# Epoch 105/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.6303 - loss: 1.0353 - val_accuracy: 0.6351 - val_loss: 0.9716
# Epoch 106/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.5932 - loss: 1.0638 - val_accuracy: 0.6737 - val_loss: 0.9442
# Epoch 107/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.5379 - loss: 1.0980 - val_accuracy: 0.6667 - val_loss: 0.9892
# Epoch 108/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.5962 - loss: 1.0418 - val_accuracy: 0.6281 - val_loss: 1.0723
# Epoch 109/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.5741 - loss: 1.0646 - val_accuracy: 0.6877 - val_loss: 0.9537
# Epoch 110/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.5901 - loss: 1.0448 - val_accuracy: 0.6491 - val_loss: 0.9892
# Epoch 111/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.5916 - loss: 1.0611 - val_accuracy: 0.6807 - val_loss: 0.9779
# Epoch 112/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.5824 - loss: 1.0413 - val_accuracy: 0.6211 - val_loss: 1.0642
# Epoch 113/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.5837 - loss: 1.0754 - val_accuracy: 0.6842 - val_loss: 0.9396
# Epoch 114/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.6436 - loss: 0.9815 - val_accuracy: 0.7193 - val_loss: 0.9178
# Epoch 115/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.5806 - loss: 1.0439 - val_accuracy: 0.6807 - val_loss: 0.9326
# Epoch 116/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.6154 - loss: 1.0269 - val_accuracy: 0.6702 - val_loss: 0.9541
# Epoch 117/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5919 - loss: 1.0264 - val_accuracy: 0.6632 - val_loss: 0.9542
# Epoch 118/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.6227 - loss: 0.9747 - val_accuracy: 0.7228 - val_loss: 0.9055
# Epoch 119/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.6421 - loss: 1.0158 - val_accuracy: 0.7053 - val_loss: 0.8965
# Epoch 120/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.6161 - loss: 1.0365 - val_accuracy: 0.6316 - val_loss: 0.9947
# Epoch 121/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.6378 - loss: 0.9663 - val_accuracy: 0.6737 - val_loss: 0.9273
# Epoch 122/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.5962 - loss: 0.9993 - val_accuracy: 0.6982 - val_loss: 0.9072
# Epoch 123/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.6176 - loss: 1.0136 - val_accuracy: 0.6421 - val_loss: 0.9593
# Epoch 124/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.5921 - loss: 1.0496 - val_accuracy: 0.6667 - val_loss: 0.9440
# Epoch 125/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.6249 - loss: 0.9646 - val_accuracy: 0.6175 - val_loss: 1.0010
# Epoch 126/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.6377 - loss: 1.0149 - val_accuracy: 0.7158 - val_loss: 0.8407
# Epoch 127/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.6544 - loss: 0.9837 - val_accuracy: 0.7404 - val_loss: 0.8455
# Epoch 128/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.5957 - loss: 1.0202 - val_accuracy: 0.6877 - val_loss: 0.9015
# Epoch 129/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.6354 - loss: 0.9691 - val_accuracy: 0.6596 - val_loss: 0.9828
# Epoch 130/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.6502 - loss: 0.9581 - val_accuracy: 0.6877 - val_loss: 0.9046
# Epoch 131/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.6106 - loss: 0.9595 - val_accuracy: 0.6807 - val_loss: 0.8946
# Epoch 132/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.6372 - loss: 0.9761 - val_accuracy: 0.6842 - val_loss: 0.9270
# Epoch 133/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.6472 - loss: 0.9169 - val_accuracy: 0.6596 - val_loss: 1.0069
# Epoch 134/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.6301 - loss: 0.9705 - val_accuracy: 0.7333 - val_loss: 0.7901
# Epoch 135/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.6168 - loss: 1.0233 - val_accuracy: 0.7053 - val_loss: 0.9185
# Epoch 136/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.6316 - loss: 0.9735 - val_accuracy: 0.6421 - val_loss: 0.9788
# Epoch 137/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.6351 - loss: 0.9688 - val_accuracy: 0.6947 - val_loss: 0.8830
# Epoch 138/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.6340 - loss: 0.9454 - val_accuracy: 0.7649 - val_loss: 0.7636
# Epoch 139/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.6420 - loss: 0.9360 - val_accuracy: 0.7474 - val_loss: 0.7972
# Epoch 140/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.6428 - loss: 0.9324 - val_accuracy: 0.6982 - val_loss: 0.8629
# Epoch 141/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.6835 - loss: 0.8702 - val_accuracy: 0.7579 - val_loss: 0.8068
# Epoch 142/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.6400 - loss: 0.9618 - val_accuracy: 0.6561 - val_loss: 1.0159
# Epoch 143/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.6146 - loss: 0.9416 - val_accuracy: 0.7298 - val_loss: 0.8741
# Epoch 144/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.6752 - loss: 0.8791 - val_accuracy: 0.7404 - val_loss: 0.8288
# Epoch 145/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.6963 - loss: 0.8722 - val_accuracy: 0.7474 - val_loss: 0.7942
# Epoch 146/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.6413 - loss: 0.9148 - val_accuracy: 0.6877 - val_loss: 0.8506
# Epoch 147/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.6753 - loss: 0.9116 - val_accuracy: 0.7509 - val_loss: 0.7964
# Epoch 148/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.6468 - loss: 0.8976 - val_accuracy: 0.6807 - val_loss: 0.8792
# Epoch 149/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.6556 - loss: 0.8779 - val_accuracy: 0.7789 - val_loss: 0.7817
# Epoch 150/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.6501 - loss: 0.8758 - val_accuracy: 0.7439 - val_loss: 0.7852

# %% [markdown]
# 4.Accuracy graph

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
epochs_range = range(1, len(acc) + 1)

plt.figure(figsize=(10, 6))
plt.plot(epochs_range, acc, 'o-', label='Training Accuracy')
plt.plot(epochs_range, val_acc, 's-', label='Validation Accuracy')
plt.title('Training vs Validation Accuracy (basic model)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 5.Evaluate model (classification_report, confusion_matrix)

# %%
from sklearn.metrics import classification_report, confusion_matrix , accuracy_score
import seaborn as sns


Y_pred = model.predict(test_generator)
y_pred = np.argmax(Y_pred, axis=1)

true_labels = test_generator.classes
class_names = list(test_generator.class_indices.keys())

# Classification report
print(classification_report(true_labels, y_pred, target_names=class_names))

# Training and Validation Accuracy
train_acc = history.history['accuracy'][-1]
val_acc = history.history['val_accuracy'][-1]

print(f"Final Training Accuracy: {train_acc * 100:.2f}%")
print(f"Final Validation Accuracy: {val_acc * 100:.2f}%")

# Confusion Matrix
cm = confusion_matrix(true_labels, y_pred)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=class_names, yticklabels=class_names, cmap="Blues")
plt.xlabel('Predicted')
plt.ylabel('Basic Model Confusion Matrix')
plt.show()
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#               precision    recall  f1-score   support
#
#      Neutral       0.61      0.74      0.67        42
#        angry       0.83      0.78      0.80        45
#      disgust       0.66      0.71      0.68        41
#         fear       0.67      0.73      0.70        41
#        happy       0.74      0.72      0.73        40
#          sad       0.62      0.49      0.55        41
#     surprise       0.91      0.85      0.88        47
#
#     accuracy                           0.72       297
#    macro avg       0.72      0.72      0.72       297
# weighted avg       0.73      0.72      0.72       297
#
# Final Training Accuracy: 65.90%
# Final Validation Accuracy: 74.39%

# %% [markdown]
# 6.balance learning to avoid bias

# %%
from sklearn.utils.class_weight import compute_class_weight

y_train = train_generator.classes
class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(y_train), y=y_train)
class_weights_dict = dict(enumerate(class_weights))

print("Class Weights:", class_weights_dict)
# Out:
# Class Weights: {0: 1.0342261904761905, 1: 0.9193121693121693, 2: 0.9108781127129751, 3: 0.9928571428571429, 4: 0.9928571428571429, 5: 1.1962134251290877, 6: 1.002886002886003}

# %% [markdown]
# 7.Enhancment model

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization

model = Sequential()

model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(64, 64, 3)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.3))  # Reguralization

model.add(Dense(7, activation='softmax'))

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_24"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_69 (Conv2D)              │ (None, 64, 64, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_36          │ (None, 64, 64, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_69 (MaxPooling2D) │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_70 (Conv2D)              │ (None, 32, 32, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_37          │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_70 (MaxPooling2D) │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_71 (Conv2D)              │ (None, 16, 16, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_38          │ (None, 16, 16, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_71 (MaxPooling2D) │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_19 (Flatten)            │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_66 (Dense)                │ (None, 128)            │     1,048,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_53 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_67 (Dense)                │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,143,751 (4.36 MB)
#  Trainable params: 1,143,303 (4.36 MB)
#  Non-trainable params: 448 (1.75 KB)

# %% [markdown]
# 8.Train enhancment model

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor='val_accuracy', patience=15, restore_best_weights=True)

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=150,
    callbacks=[early_stop],
    class_weight=class_weights_dict
)
# Out:
# Epoch 1/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.2006 - loss: 2.7381 - val_accuracy: 0.1719 - val_loss: 1.9411
# Epoch 2/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.2822 - loss: 1.9369 - val_accuracy: 0.1754 - val_loss: 2.0791
# Epoch 3/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.3273 - loss: 1.6962 - val_accuracy: 0.2070 - val_loss: 2.2961
# Epoch 4/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.3337 - loss: 1.6781 - val_accuracy: 0.1368 - val_loss: 2.4802
# Epoch 5/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.3762 - loss: 1.5614 - val_accuracy: 0.1474 - val_loss: 2.7199
# Epoch 6/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.3741 - loss: 1.5989 - val_accuracy: 0.1825 - val_loss: 2.8893
# Epoch 7/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.3759 - loss: 1.5815 - val_accuracy: 0.2035 - val_loss: 2.9347
# Epoch 8/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.3776 - loss: 1.5710 - val_accuracy: 0.1789 - val_loss: 3.0118
# Epoch 9/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.4147 - loss: 1.5109 - val_accuracy: 0.1684 - val_loss: 3.0893
# Epoch 10/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.4396 - loss: 1.4314 - val_accuracy: 0.1789 - val_loss: 2.8812
# Epoch 11/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.4586 - loss: 1.4609 - val_accuracy: 0.2316 - val_loss: 2.6156
# Epoch 12/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.4484 - loss: 1.4102 - val_accuracy: 0.2351 - val_loss: 2.7042
# Epoch 13/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.4472 - loss: 1.4279 - val_accuracy: 0.2947 - val_loss: 2.5285
# Epoch 14/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.4477 - loss: 1.4066 - val_accuracy: 0.2737 - val_loss: 2.4654
# Epoch 15/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.4979 - loss: 1.3439 - val_accuracy: 0.2842 - val_loss: 2.2721
# Epoch 16/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.4504 - loss: 1.3933 - val_accuracy: 0.2982 - val_loss: 2.1735
# Epoch 17/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.4656 - loss: 1.3398 - val_accuracy: 0.3333 - val_loss: 2.0000
# Epoch 18/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.5129 - loss: 1.2935 - val_accuracy: 0.4105 - val_loss: 1.7282
# Epoch 19/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.5296 - loss: 1.2520 - val_accuracy: 0.4000 - val_loss: 1.5840
# Epoch 20/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.4878 - loss: 1.2834 - val_accuracy: 0.4842 - val_loss: 1.3906
# Epoch 21/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.4921 - loss: 1.2434 - val_accuracy: 0.5333 - val_loss: 1.3198
# Epoch 22/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.5385 - loss: 1.2177 - val_accuracy: 0.5228 - val_loss: 1.2415
# Epoch 23/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.5501 - loss: 1.1536 - val_accuracy: 0.6070 - val_loss: 1.0957
# Epoch 24/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.5196 - loss: 1.1987 - val_accuracy: 0.6596 - val_loss: 1.0057
# Epoch 25/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.5466 - loss: 1.1850 - val_accuracy: 0.6667 - val_loss: 0.9689
# Epoch 26/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.5812 - loss: 1.1537 - val_accuracy: 0.7228 - val_loss: 0.8602
# Epoch 27/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.5486 - loss: 1.1961 - val_accuracy: 0.7439 - val_loss: 0.8154
# Epoch 28/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.5485 - loss: 1.1456 - val_accuracy: 0.7439 - val_loss: 0.8028
# Epoch 29/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.5790 - loss: 1.0811 - val_accuracy: 0.7684 - val_loss: 0.7569
# Epoch 30/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.5624 - loss: 1.1543 - val_accuracy: 0.7860 - val_loss: 0.7429
# Epoch 31/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.5906 - loss: 1.0637 - val_accuracy: 0.7509 - val_loss: 0.7515
# Epoch 32/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6237 - loss: 1.0222 - val_accuracy: 0.7404 - val_loss: 0.7323
# Epoch 33/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.5306 - loss: 1.1205 - val_accuracy: 0.7404 - val_loss: 0.7192
# Epoch 34/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.6025 - loss: 1.0407 - val_accuracy: 0.7544 - val_loss: 0.7059
# Epoch 35/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.6240 - loss: 1.0733 - val_accuracy: 0.7509 - val_loss: 0.6926
# Epoch 36/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.5788 - loss: 1.0260 - val_accuracy: 0.7649 - val_loss: 0.7012
# Epoch 37/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.6060 - loss: 1.0057 - val_accuracy: 0.7684 - val_loss: 0.6690
# Epoch 38/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.6034 - loss: 1.0672 - val_accuracy: 0.7719 - val_loss: 0.6822
# Epoch 39/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.6100 - loss: 1.0236 - val_accuracy: 0.7930 - val_loss: 0.6379
# Epoch 40/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.6425 - loss: 0.9762 - val_accuracy: 0.7895 - val_loss: 0.6590
# Epoch 41/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.6116 - loss: 0.9671 - val_accuracy: 0.7649 - val_loss: 0.6232
# Epoch 42/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.6270 - loss: 0.9421 - val_accuracy: 0.7719 - val_loss: 0.6248
# Epoch 43/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.6525 - loss: 0.9918 - val_accuracy: 0.7860 - val_loss: 0.6084
# Epoch 44/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.6270 - loss: 0.9668 - val_accuracy: 0.7860 - val_loss: 0.6076
# Epoch 45/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.6623 - loss: 0.9485 - val_accuracy: 0.8000 - val_loss: 0.5645
# Epoch 46/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.6723 - loss: 0.8754 - val_accuracy: 0.8140 - val_loss: 0.5405
# Epoch 47/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.6458 - loss: 0.9551 - val_accuracy: 0.8526 - val_loss: 0.5477
# Epoch 48/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.6386 - loss: 0.9357 - val_accuracy: 0.8246 - val_loss: 0.5432
# Epoch 49/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.6920 - loss: 0.8587 - val_accuracy: 0.8000 - val_loss: 0.5485
# Epoch 50/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6383 - loss: 0.8852 - val_accuracy: 0.8105 - val_loss: 0.5623
# Epoch 51/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - accuracy: 0.6644 - loss: 0.8820 - val_accuracy: 0.8421 - val_loss: 0.5022
# Epoch 52/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.6756 - loss: 0.8556 - val_accuracy: 0.8316 - val_loss: 0.5164
# Epoch 53/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.6648 - loss: 0.8809 - val_accuracy: 0.8316 - val_loss: 0.4919
# Epoch 54/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.6740 - loss: 0.8523 - val_accuracy: 0.8386 - val_loss: 0.4900
# Epoch 55/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.6733 - loss: 0.8501 - val_accuracy: 0.8632 - val_loss: 0.4828
# Epoch 56/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.6848 - loss: 0.8130 - val_accuracy: 0.8596 - val_loss: 0.4599
# Epoch 57/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.7050 - loss: 0.8047 - val_accuracy: 0.8667 - val_loss: 0.4692
# Epoch 58/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.6744 - loss: 0.8565 - val_accuracy: 0.8421 - val_loss: 0.4980
# Epoch 59/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.7019 - loss: 0.8090 - val_accuracy: 0.8737 - val_loss: 0.4355
# Epoch 60/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.6746 - loss: 0.7799 - val_accuracy: 0.8842 - val_loss: 0.4493
# Epoch 61/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - accuracy: 0.7126 - loss: 0.7592 - val_accuracy: 0.8456 - val_loss: 0.4575
# Epoch 62/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.7472 - loss: 0.7762 - val_accuracy: 0.8912 - val_loss: 0.4182
# Epoch 63/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.7202 - loss: 0.7540 - val_accuracy: 0.8807 - val_loss: 0.4166
# Epoch 64/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.6870 - loss: 0.8455 - val_accuracy: 0.8702 - val_loss: 0.4212
# Epoch 65/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.7387 - loss: 0.6973 - val_accuracy: 0.8772 - val_loss: 0.3976
# Epoch 66/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.7352 - loss: 0.7209 - val_accuracy: 0.8912 - val_loss: 0.3878
# Epoch 67/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.7239 - loss: 0.7013 - val_accuracy: 0.8982 - val_loss: 0.3882
# Epoch 68/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.7257 - loss: 0.6780 - val_accuracy: 0.8982 - val_loss: 0.3604
# Epoch 69/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.7149 - loss: 0.7601 - val_accuracy: 0.9298 - val_loss: 0.3178
# Epoch 70/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.7445 - loss: 0.6935 - val_accuracy: 0.8947 - val_loss: 0.3519
# Epoch 71/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.7292 - loss: 0.7323 - val_accuracy: 0.9123 - val_loss: 0.3335
# Epoch 72/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.7462 - loss: 0.6690 - val_accuracy: 0.9193 - val_loss: 0.3431
# Epoch 73/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.7652 - loss: 0.6429 - val_accuracy: 0.9018 - val_loss: 0.3518
# Epoch 74/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.7328 - loss: 0.7337 - val_accuracy: 0.9158 - val_loss: 0.3350
# Epoch 75/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.7750 - loss: 0.6297 - val_accuracy: 0.9088 - val_loss: 0.3072
# Epoch 76/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.7556 - loss: 0.6946 - val_accuracy: 0.9228 - val_loss: 0.3035
# Epoch 77/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.7566 - loss: 0.6727 - val_accuracy: 0.9404 - val_loss: 0.2642
# Epoch 78/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - accuracy: 0.7739 - loss: 0.6262 - val_accuracy: 0.9439 - val_loss: 0.2580
# Epoch 79/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.7392 - loss: 0.6417 - val_accuracy: 0.9509 - val_loss: 0.2581
# Epoch 80/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - accuracy: 0.7604 - loss: 0.6166 - val_accuracy: 0.9579 - val_loss: 0.2525
# Epoch 81/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.7226 - loss: 0.6803 - val_accuracy: 0.9649 - val_loss: 0.2386
# Epoch 82/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.8038 - loss: 0.5653 - val_accuracy: 0.9649 - val_loss: 0.2261
# Epoch 83/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.7881 - loss: 0.5914 - val_accuracy: 0.9333 - val_loss: 0.2911
# Epoch 84/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.7464 - loss: 0.6575 - val_accuracy: 0.9719 - val_loss: 0.2371
# Epoch 85/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.8174 - loss: 0.5772 - val_accuracy: 0.9719 - val_loss: 0.2307
# Epoch 86/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.7807 - loss: 0.6050 - val_accuracy: 0.9193 - val_loss: 0.2472
# Epoch 87/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.7553 - loss: 0.6113 - val_accuracy: 0.9439 - val_loss: 0.2270
# Epoch 88/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.7793 - loss: 0.5811 - val_accuracy: 0.9684 - val_loss: 0.2133
# Epoch 89/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.7696 - loss: 0.6322 - val_accuracy: 0.9404 - val_loss: 0.2265
# Epoch 90/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.8191 - loss: 0.5487 - val_accuracy: 0.9298 - val_loss: 0.2716
# Epoch 91/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.7841 - loss: 0.5668 - val_accuracy: 0.9509 - val_loss: 0.2321
# Epoch 92/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.8087 - loss: 0.5251 - val_accuracy: 0.9719 - val_loss: 0.1953
# Epoch 93/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.7918 - loss: 0.5815 - val_accuracy: 0.9860 - val_loss: 0.1758
# Epoch 94/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.7927 - loss: 0.5653 - val_accuracy: 0.9860 - val_loss: 0.1945
# Epoch 95/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.8033 - loss: 0.5681 - val_accuracy: 0.9754 - val_loss: 0.1929
# Epoch 96/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.8101 - loss: 0.5427 - val_accuracy: 0.9895 - val_loss: 0.1691
# Epoch 97/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.7954 - loss: 0.5507 - val_accuracy: 0.9754 - val_loss: 0.1690
# Epoch 98/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.8117 - loss: 0.5226 - val_accuracy: 0.9719 - val_loss: 0.1748
# Epoch 99/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - accuracy: 0.7949 - loss: 0.5366 - val_accuracy: 0.9684 - val_loss: 0.1663
# Epoch 100/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - accuracy: 0.8155 - loss: 0.4966 - val_accuracy: 0.9439 - val_loss: 0.2114
# Epoch 101/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.7970 - loss: 0.5508 - val_accuracy: 0.9614 - val_loss: 0.1645
# Epoch 102/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.8128 - loss: 0.5602 - val_accuracy: 0.9684 - val_loss: 0.1526
# Epoch 103/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.7946 - loss: 0.5199 - val_accuracy: 0.9719 - val_loss: 0.1761
# Epoch 104/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - accuracy: 0.8279 - loss: 0.4650 - val_accuracy: 0.9825 - val_loss: 0.1572
# Epoch 105/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.7787 - loss: 0.5730 - val_accuracy: 0.9754 - val_loss: 0.1471
# Epoch 106/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - accuracy: 0.8400 - loss: 0.4728 - val_accuracy: 0.9789 - val_loss: 0.1551
# Epoch 107/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - accuracy: 0.7860 - loss: 0.5192 - val_accuracy: 0.9719 - val_loss: 0.1502
# Epoch 108/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.8455 - loss: 0.4626 - val_accuracy: 0.9719 - val_loss: 0.1479
# Epoch 109/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - accuracy: 0.8439 - loss: 0.4666 - val_accuracy: 0.9860 - val_loss: 0.1419
# Epoch 110/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.8154 - loss: 0.4695 - val_accuracy: 0.9719 - val_loss: 0.1716
# Epoch 111/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.7937 - loss: 0.5315 - val_accuracy: 0.9649 - val_loss: 0.1825

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
epochs_range = range(1, len(acc) + 1)

plt.figure(figsize=(10, 6))
plt.plot(epochs_range, acc, 'o-', label='Training Accuracy')
plt.plot(epochs_range, val_acc, 's-', label='Validation Accuracy')
plt.title('Training vs Validation Accuracy(Enhanced model)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 9.Evaluate model (classification_report, confusion_matrix)

# %%
from sklearn.metrics import  accuracy_score

Y_pred = model.predict(test_generator)
y_pred = np.argmax(Y_pred, axis=1)

true_labels = test_generator.classes
class_names = list(test_generator.class_indices.keys())

# Classification report
print(classification_report(true_labels, y_pred, target_names=class_names))

# Training and Validation Accuracy
train_acc = history.history['accuracy'][-1]
val_acc = history.history['val_accuracy'][-1]

print(f"Final Training Accuracy: {train_acc * 100:.2f}%")
print(f"Final Validation Accuracy: {val_acc * 100:.2f}%")

# Confusion Matrix
cm = confusion_matrix(true_labels, y_pred)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=class_names, yticklabels=class_names, cmap="Blues")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('enhanced Model Confusion Matrix')
plt.show()
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#               precision    recall  f1-score   support
#
#      Neutral       0.93      0.93      0.93        42
#        angry       0.96      0.98      0.97        45
#      disgust       1.00      0.88      0.94        41
#         fear       0.95      1.00      0.98        41
#        happy       1.00      0.95      0.97        40
#          sad       0.91      0.98      0.94        41
#     surprise       0.96      0.98      0.97        47
#
#     accuracy                           0.96       297
#    macro avg       0.96      0.96      0.96       297
# weighted avg       0.96      0.96      0.96       297
#
# Final Training Accuracy: 80.00%
# Final Validation Accuracy: 96.49%

# %% [markdown]
# #baseline model

# %%
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam

baseline_model = models.Sequential([
    layers.Conv2D(16, (3, 3), activation='relu', input_shape=(64, 64, 3)),
    layers.MaxPooling2D((2, 2)),

    layers.Conv2D(32, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),

    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(7, activation='softmax') 
])

baseline_model.compile(
    optimizer=Adam(learning_rate=0.001),  
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

baseline_model.summary()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_25"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_72 (Conv2D)              │ (None, 62, 62, 16)     │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_72 (MaxPooling2D) │ (None, 31, 31, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_73 (Conv2D)              │ (None, 29, 29, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_73 (MaxPooling2D) │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_20 (Flatten)            │ (None, 6272)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_68 (Dense)                │ (None, 64)             │       401,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_69 (Dense)                │ (None, 7)              │           455 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 407,015 (1.55 MB)
#  Trainable params: 407,015 (1.55 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
baseline_history = baseline_model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=30
    
)
# Out:
# Epoch 1/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.1907 - loss: 2.0065 - val_accuracy: 0.3018 - val_loss: 1.8452
# Epoch 2/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.2833 - loss: 1.8369 - val_accuracy: 0.3333 - val_loss: 1.7722
# Epoch 3/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.3377 - loss: 1.7562 - val_accuracy: 0.3404 - val_loss: 1.6713
# Epoch 4/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.3046 - loss: 1.6850 - val_accuracy: 0.3333 - val_loss: 1.6321
# Epoch 5/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.3255 - loss: 1.6568 - val_accuracy: 0.3579 - val_loss: 1.6573
# Epoch 6/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.3137 - loss: 1.6918 - val_accuracy: 0.3719 - val_loss: 1.6075
# Epoch 7/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.3526 - loss: 1.6418 - val_accuracy: 0.3684 - val_loss: 1.5846
# Epoch 8/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.3507 - loss: 1.6189 - val_accuracy: 0.4140 - val_loss: 1.5240
# Epoch 9/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.3930 - loss: 1.5284 - val_accuracy: 0.4070 - val_loss: 1.5034
# Epoch 10/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.3776 - loss: 1.5385 - val_accuracy: 0.3895 - val_loss: 1.5303
# Epoch 11/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.4174 - loss: 1.4992 - val_accuracy: 0.4070 - val_loss: 1.4576
# Epoch 12/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.4083 - loss: 1.5178 - val_accuracy: 0.3930 - val_loss: 1.5028
# Epoch 13/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.3864 - loss: 1.4853 - val_accuracy: 0.4421 - val_loss: 1.4195
# Epoch 14/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.3943 - loss: 1.4882 - val_accuracy: 0.4175 - val_loss: 1.4059
# Epoch 15/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.3850 - loss: 1.4265 - val_accuracy: 0.4386 - val_loss: 1.4202
# Epoch 16/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.3955 - loss: 1.4621 - val_accuracy: 0.4561 - val_loss: 1.3739
# Epoch 17/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.4154 - loss: 1.4335 - val_accuracy: 0.4667 - val_loss: 1.4228
# Epoch 18/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.4120 - loss: 1.4058 - val_accuracy: 0.4175 - val_loss: 1.4358
# Epoch 19/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.4222 - loss: 1.3749 - val_accuracy: 0.5018 - val_loss: 1.3071
# Epoch 20/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.4350 - loss: 1.3889 - val_accuracy: 0.4842 - val_loss: 1.3342
# Epoch 21/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.4427 - loss: 1.3671 - val_accuracy: 0.5018 - val_loss: 1.3467
# Epoch 22/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.4564 - loss: 1.2940 - val_accuracy: 0.4807 - val_loss: 1.3257
# Epoch 23/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.4459 - loss: 1.3422 - val_accuracy: 0.4947 - val_loss: 1.2901
# Epoch 24/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.4470 - loss: 1.3721 - val_accuracy: 0.5018 - val_loss: 1.2516
# Epoch 25/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.4825 - loss: 1.2628 - val_accuracy: 0.5228 - val_loss: 1.1992
# Epoch 26/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.4954 - loss: 1.2873 - val_accuracy: 0.4912 - val_loss: 1.2686
# Epoch 27/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.4572 - loss: 1.3192 - val_accuracy: 0.4596 - val_loss: 1.4201
# Epoch 28/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.4370 - loss: 1.3178 - val_accuracy: 0.5158 - val_loss: 1.2232
# Epoch 29/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.4573 - loss: 1.3162 - val_accuracy: 0.5579 - val_loss: 1.1874
# Epoch 30/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.5168 - loss: 1.2546 - val_accuracy: 0.5193 - val_loss: 1.1947

# %%
plt.plot(baseline_history.history['accuracy'], label='Train Accuracy')
plt.plot(baseline_history.history['val_accuracy'], label='Val Accuracy')
plt.title('Baseline CNN Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns  


baseline_pred = baseline_model.predict(test_generator)
baseline_y_pred = np.argmax(baseline_pred, axis=1)
baseline_true_labels = test_generator.classes

print(classification_report(baseline_true_labels, baseline_y_pred, target_names=class_names))

train_acc = baseline_history.history['accuracy'][-1]
val_acc = baseline_history.history['val_accuracy'][-1]

print(f"Final Training Accuracy: {train_acc * 100:.2f}%")
print(f"Final Validation Accuracy: {val_acc * 100:.2f}%")

cm = confusion_matrix(baseline_true_labels, baseline_y_pred)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=class_names, yticklabels=class_names, cmap="Oranges")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Baseline Model Confusion Matrix')
plt.show()
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#               precision    recall  f1-score   support
#
#      Neutral       0.61      0.26      0.37        42
#        angry       0.62      0.67      0.65        45
#      disgust       0.42      0.54      0.47        41
#         fear       0.48      0.37      0.42        41
#        happy       0.48      0.65      0.55        40
#          sad       0.55      0.39      0.46        41
#     surprise       0.68      0.94      0.79        47
#
#     accuracy                           0.55       297
#    macro avg       0.55      0.54      0.53       297
# weighted avg       0.55      0.55      0.53       297
#
# Final Training Accuracy: 50.50%
# Final Validation Accuracy: 51.93%
